# %%
import numpy as np
import pandas as pd

# Visualization
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.pyplot import pie, axis, show

import seaborn as sns # For mathematical calculations
import matplotlib.pyplot as plt  # For plotting graphs
from datetime import datetime    # To access datetime

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_csv('dataset_thonny_logs.csv')
# Out:
# c:\users\alexf\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (21,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
def display_all(df):
    with pd.option_context("display.max_row", 100, "display.max_columns", 100):
        display(df)
display_all(df.head())
# Out:
#          view_id     view_class           sequence  \
# 0      ShellView      ShellView           ShowView
# 1  AssistantView  AssistantView           ShowView
# 2            NaN            NaN  EditorTextCreated
# 3            NaN            NaN            NewFile
# 4      ShellView      ShellView           ShowView
#
#                          time  student_ID   editor_id editor_class  \
# 0  2020-03-23T14:33:24.525803         1.0         NaN          NaN
# 1  2020-03-23T14:33:24.543817         1.0         NaN          NaN
# 2  2020-03-23T14:33:24.578842         1.0  75874928.0       Editor
# 3  2020-03-23T14:33:24.579842         1.0  75874928.0       Editor
# 4  2020-03-23T14:33:24.579842         1.0         NaN          NaN
#
#    text_widget_id text_widget_class  widget_id widget_class  index text tags  \
# 0             NaN               NaN        NaN          NaN    NaN  NaN  NaN
# 1             NaN               NaN        NaN          NaN    NaN  NaN  NaN
# 2      75874448.0      CodeViewText        NaN          NaN    NaN  NaN  NaN
# 3      75874448.0      CodeViewText        NaN          NaN    NaN  NaN  NaN
# 4             NaN               NaN        NaN          NaN    NaN  NaN  NaN
#
#   trivial_for_coloring trivial_for_parens text_widget_context  index1 index2  \
# 0                  NaN                NaN                 NaN     NaN    NaN
# 1                  NaN                NaN                 NaN     NaN    NaN
# 2                  NaN                NaN                 NaN     NaN    NaN
# 3                  NaN                NaN                 NaN     NaN    NaN
# 4                  NaN                NaN                 NaN     NaN    NaN
#
#   error_type filename save_copy cmd_line command_text input_text widget  \
# 0        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 1        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 2        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 3        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 4        NaN      NaN       NaN      NaN          NaN        NaN    NaN
#
#   command_id denied
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN

# %%
df.describe().T
# Out:
#                     count          mean           std        min          25%  \
# student_ID      2109853.0  5.675439e+01  3.104495e+01        1.0        29.00
# editor_id         26873.0  2.498610e+12  1.854013e+13  1598960.0  70105488.00
# text_widget_id  1953485.0  2.546304e+12  1.871241e+13  1597616.0  70878544.00
# widget_id        334764.0  1.543278e+12  1.462028e+13  1597616.0  56461008.00
# index           1537730.0  1.022425e+03  1.744272e+03        1.0         9.17
# index1           265869.0  4.963397e+01  2.528429e+02        1.0         5.90
#
#                         50%           75%           max
# student_ID            61.00  8.400000e+01  1.060000e+02
# editor_id       81174512.00  1.517544e+08  1.406988e+14
# text_widget_id  80207152.00  1.694847e+08  1.406988e+14
# widget_id       74537168.00  1.163127e+08  1.406989e+14
# index                 37.17  1.430000e+03  6.981000e+03
# index1                13.15  3.411000e+01  6.812000e+03

# %% [markdown]
# # Information about Missing values

# %%
msno.matrix(df)
plt.show()

# %%
msno.bar(df,sort='descending',color='#33A1FF')
plt.show()

# %%
def Missing_Values(df):
    variable_name = []
    total_value = []
    total_missing_value = []
    missing_value_rate = []
    unique_value_list = []
    total_unique_value = []
    data_type = []
    
    for col in df.columns:
        variable_name.append(col)
        data_type.append(df[col].dtype)
        total_value.append(df[col].shape[0])
        total_missing_value.append(df[col].isnull().sum())
        missing_value_rate.append(round(df[col].isnull().sum()/df[col].shape[0],4))


        
    missing_data=pd.DataFrame({"Variable":variable_name,\
                               "Total_Value":total_value,\
                               "Total_Missing_Value":total_missing_value,\
                               "%_Missing_Value_Rate":missing_value_rate,\
                               "Data_Type":data_type\

                              })
    
    missing_data = missing_data.set_index("Variable")
    return missing_data.sort_values("Total_Missing_Value",ascending=False)

dataframe_info = Missing_Values(df)
dataframe_info
# Out:
#                       Total_Value  Total_Missing_Value  %_Missing_Value_Rate  \
# Variable
# denied                    2236969              2236960                1.0000
# command_id                2236969              2236960                1.0000
# widget                    2236969              2236871                1.0000
# save_copy                 2236969              2235401                0.9993
# input_text                2236969              2230419                0.9971
# error_type                2236969              2229678                0.9967
# view_class                2236969              2223790                0.9941
# view_id                   2236969              2223790                0.9941
# cmd_line                  2236969              2215338                0.9903
# filename                  2236969              2215136                0.9902
# editor_id                 2236969              2210096                0.9880
# editor_class              2236969              2210096                0.9880
# command_text              2236969              2206703                0.9865
# index2                    2236969              1971100                0.8811
# index1                    2236969              1971100                0.8811
# widget_class              2236969              1902205                0.8503
# widget_id                 2236969              1902205                0.8503
# text_widget_context       2236969              1361753                0.6087
# text                      2236969               709127                0.3170
# index                     2236969               699239                0.3126
# tags                      2236969               699239                0.3126
# trivial_for_coloring      2236969               464715                0.2077
# trivial_for_parens        2236969               464715                0.2077
# text_widget_id            2236969               283484                0.1267
# text_widget_class         2236969               283484                0.1267
# student_ID                2236969               127116                0.0568
# time                      2236969                    0                0.0000
# sequence                  2236969                    0                0.0000
#
#                      Data_Type
# Variable
# denied                  object
# command_id              object
# widget                  object
# save_copy               object
# input_text              object
# error_type              object
# view_class              object
# view_id                 object
# cmd_line                object
# filename                object
# editor_id              float64
# editor_class            object
# command_text            object
# index2                  object
# index1                 float64
# widget_class            object
# widget_id              float64
# text_widget_context     object
# text                    object
# index                  float64
# tags                    object
# trivial_for_coloring    object
# trivial_for_parens      object
# text_widget_id         float64
# text_widget_class       object
# student_ID             float64
# time                    object
# sequence                object

# %% [markdown]
# Heatmap

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['denied','command_id', 'widget'])
# Out:
#                view_id     view_class           sequence  \
# 0            ShellView      ShellView           ShowView
# 1        AssistantView  AssistantView           ShowView
# 2                  NaN            NaN  EditorTextCreated
# 3                  NaN            NaN            NewFile
# 4            ShellView      ShellView           ShowView
# ...                ...            ...                ...
# 2236964            NaN            NaN         TextInsert
# 2236965            NaN            NaN         <FocusOut>
# 2236966            NaN            NaN          <FocusIn>
# 2236967            NaN            NaN         <Button-1>
# 2236968            NaN            NaN         <Button-1>
#
#                                time  student_ID   editor_id editor_class  \
# 0        2020-03-23T14:33:24.525803         1.0         NaN          NaN
# 1        2020-03-23T14:33:24.543817         1.0         NaN          NaN
# 2        2020-03-23T14:33:24.578842         1.0  75874928.0       Editor
# 3        2020-03-23T14:33:24.579842         1.0  75874928.0       Editor
# 4        2020-03-23T14:33:24.579842         1.0         NaN          NaN
# ...                             ...         ...         ...          ...
# 2236964  2020-05-14T15:59:38.295567        99.0         NaN          NaN
# 2236965  2020-05-14T15:59:39.585641        99.0         NaN          NaN
# 2236966  2020-05-14T16:00:44.554357        99.0         NaN          NaN
# 2236967  2020-05-14T16:00:48.339574        99.0         NaN          NaN
# 2236968  2020-05-14T16:00:49.563644        99.0         NaN          NaN
#
#          text_widget_id text_widget_class   widget_id  ... trivial_for_parens  \
# 0                   NaN               NaN         NaN  ...                NaN
# 1                   NaN               NaN         NaN  ...                NaN
# 2            75874448.0      CodeViewText         NaN  ...                NaN
# 3            75874448.0      CodeViewText         NaN  ...                NaN
# 4                   NaN               NaN         NaN  ...                NaN
# ...                 ...               ...         ...  ...                ...
# 2236964      62161040.0         ShellText         NaN  ...              False
# 2236965             NaN               NaN  13183728.0  ...                NaN
# 2236966             NaN               NaN  13183728.0  ...                NaN
# 2236967             NaN               NaN  62069616.0  ...                NaN
# 2236968             NaN               NaN  62069616.0  ...                NaN
#
#          text_widget_context index1 index2 error_type filename save_copy  \
# 0                        NaN    NaN    NaN        NaN      NaN       NaN
# 1                        NaN    NaN    NaN        NaN      NaN       NaN
# 2                        NaN    NaN    NaN        NaN      NaN       NaN
# 3                        NaN    NaN    NaN        NaN      NaN       NaN
# 4                        NaN    NaN    NaN        NaN      NaN       NaN
# ...                      ...    ...    ...        ...      ...       ...
# 2236964                shell    NaN    NaN        NaN      NaN       NaN
# 2236965                  NaN    NaN    NaN        NaN      NaN       NaN
# 2236966                  NaN    NaN    NaN        NaN      NaN       NaN
# 2236967                  NaN    NaN    NaN        NaN      NaN       NaN
# 2236968                  NaN    NaN    NaN        NaN      NaN       NaN
#
#          cmd_line command_text input_text
# 0             NaN          NaN        NaN
# 1             NaN          NaN        NaN
# 2             NaN          NaN        NaN
# 3             NaN          NaN        NaN
# 4             NaN          NaN        NaN
# ...           ...          ...        ...
# 2236964       NaN          NaN        NaN
# 2236965       NaN          NaN        NaN
# 2236966       NaN          NaN        NaN
# 2236967       NaN          NaN        NaN
# 2236968       NaN          NaN        NaN
#
# [2236969 rows x 25 columns]

# %% [markdown]
# # Datetime

# %%
df['time'] = pd.to_datetime(df['time'])

# %% [markdown]
# # Errors

# %%
df_errors = df[df['error_type'].notna()]
#df_errors = df[df['text'].str.contains("Error", na=False)]
display_all(df_errors.head())
# Out:
#     view_id view_class    sequence                       time  student_ID  \
# 20      NaN        NaN  TextInsert 2020-03-23 14:33:52.646012         1.0
# 101     NaN        NaN  TextInsert 2020-03-23 14:38:45.693829         1.0
# 137     NaN        NaN  TextInsert 2020-03-23 14:39:53.491679         1.0
# 170     NaN        NaN  TextInsert 2020-03-23 14:41:16.309866         1.0
# 189     NaN        NaN  TextInsert 2020-03-23 14:41:29.322084         1.0
#
#      editor_id editor_class  text_widget_id text_widget_class  widget_id  \
# 20         NaN          NaN      78015664.0     BaseShellText        NaN
# 101        NaN          NaN      54768912.0         ShellText        NaN
# 137        NaN          NaN      54768912.0         ShellText        NaN
# 170        NaN          NaN      54768912.0         ShellText        NaN
# 189        NaN          NaN      54768912.0         ShellText        NaN
#
#     widget_class  index                                               text  \
# 20           NaN    4.0  ValueError: invalid literal for int() with bas...
# 101          NaN    8.0         NameError: name 'forward' is not defined\n
# 137          NaN   15.0         NameError: name 'forward' is not defined\n
# 170          NaN   22.0         NameError: name 'forward' is not defined\n
# 189          NaN    7.0         NameError: name 'forward' is not defined\n
#
#                  tags trivial_for_coloring trivial_for_parens  \
# 20   ('io', 'stderr')                False              False
# 101  ('io', 'stderr')                False              False
# 137  ('io', 'stderr')                False              False
# 170  ('io', 'stderr')                False              False
# 189  ('io', 'stderr')                False              False
#
#     text_widget_context  index1 index2  error_type filename save_copy  \
# 20                  NaN     NaN    NaN  ValueError      NaN       NaN
# 101               shell     NaN    NaN   NameError      NaN       NaN
# 137               shell     NaN    NaN   NameError      NaN       NaN
# 170               shell     NaN    NaN   NameError      NaN       NaN
# 189               shell     NaN    NaN   NameError      NaN       NaN
#
#     cmd_line command_text input_text widget command_id denied
# 20       NaN          NaN        NaN    NaN        NaN    NaN
# 101      NaN          NaN        NaN    NaN        NaN    NaN
# 137      NaN          NaN        NaN    NaN        NaN    NaN
# 170      NaN          NaN        NaN    NaN        NaN    NaN
# 189      NaN          NaN        NaN    NaN        NaN    NaN

# %%
df_errors.shape
# Out:
# (7291, 28)

# %% [markdown]
# Print number of errors during the laboratory lessons grouped by the months

# %%
#as string
df_errors['error_type'].astype(str)


fig, axs = plt.subplots(figsize=(12, 4))
df_errors.groupby(df_errors["time"].dt.month)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Month")
plt.ylabel("Number of Errors")
# Out:
# Text(0, 0.5, 'Number of Errors')

# %% [markdown]
# Print number of errors during the laboratory lessons grouped by the days of the months

# %%
df_grouped_month = df_errors.groupby(df_errors["time"].dt.month)

for group_name, df_group in df_grouped_month:
    fig, axs = plt.subplots(figsize=(12, 4))
    df_group.groupby(df_group["time"].dt.day)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
    plt.xlabel("Days of the month "+str(group_name))
    plt.ylabel("Number of Errors")

# %% [markdown]
# Pie charts

# %% [markdown]
# Errors data cleaning

# %%
#df['prod_type'] = df['prod_type'].replace({'respon':'responsive', 'r':'responsive'})




df.drop(index=df[df['error_type'] == 'd={1'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Errore'].index, inplace=True)
df.drop(index=df[df['error_type'] == '    raise LookupError()'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'def reverse_lookup(d, v)'].index, inplace=True)
df.drop(index=df[df['error_type'] == '## turtle.py'].index, inplace=True)

df.drop(index=df[df['error_type'] == "%Run 'Lab_07 RangeError.py'"].index, inplace=True)

df.drop(index=df[df['error_type'] == 'Help on built-in function remove'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class list in module builtins'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class range in module builtins'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class str in module builtins'].index, inplace=True)



#df.drop(index=df[df['error_type'].str.contains("raise")].index, inplace=True)

#df.drop(df['error_type'].str.contains(r'[Lookup]').index)


new_df_errors = df[df['error_type'].notna()]

# %%
new_df_errors.groupby(['error_type']).groups.keys()
# Out:
# dict_keys(['AssertionError', 'AttributeError', 'FileNotFoundError', 'ImportError', 'IndentationError', 'IndexError', 'KeyError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'RecursionError', 'SyntaxError', 'TabError', 'TypeError', 'UnboundLocalError', 'ValueError', 'ZeroDivisionError', '_tkinter.TclError', 'turtle.TurtleGraphicsError'])

# %%
plt.figure(figsize=(20, 10))
new_df_errors.groupby(['error_type'])['error_type'].count().plot(kind='barh') 
plt.xlabel("Number of Errors")
plt.ylabel("Error type")
# Out:
# Text(0, 0.5, 'Error type')

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x=new_df_errors['error_type'], data=new_df_errors, palette="pastel", edgecolor=".3")

plt.show()

# %% [markdown]
# Mean of errors per student

# %%
#Mean of errors per student
new_df_errors.groupby(['student_ID'])['error_type'].count().mean()
# Out:
# 78.20430107526882

# %% [markdown]
# # Numer of Run

# %%
#df with Run 

df_command_text= df[df['command_text'].notna()]

df_run = df_command_text[df_command_text['command_text'].str.contains("%Run")]

#df_run.groupby(['student_ID'])['command_text'].count()

# %%
df_run
# Out:
#         view_id view_class      sequence                       time  \
# 90          NaN        NaN  ShellCommand 2020-03-23 14:38:44.843547
# 126         NaN        NaN  ShellCommand 2020-03-23 14:39:53.154439
# 159         NaN        NaN  ShellCommand 2020-03-23 14:41:15.973628
# 178         NaN        NaN  ShellCommand 2020-03-23 14:41:28.986765
# 246         NaN        NaN  ShellCommand 2020-03-23 14:42:48.519844
# ...         ...        ...           ...                        ...
# 2236463     NaN        NaN  ShellCommand 2020-05-14 15:55:45.011224
# 2236558     NaN        NaN  ShellCommand 2020-05-14 15:56:25.143520
# 2236567     NaN        NaN  ShellCommand 2020-05-14 15:56:28.485711
# 2236918     NaN        NaN  ShellCommand 2020-05-14 15:59:20.885571
# 2236951     NaN        NaN  ShellCommand 2020-05-14 15:59:35.612414
#
#          student_ID  editor_id editor_class  text_widget_id text_widget_class  \
# 90              1.0        NaN          NaN             NaN               NaN
# 126             1.0        NaN          NaN             NaN               NaN
# 159             1.0        NaN          NaN             NaN               NaN
# 178             1.0        NaN          NaN             NaN               NaN
# 246             1.0        NaN          NaN             NaN               NaN
# ...             ...        ...          ...             ...               ...
# 2236463        99.0        NaN          NaN             NaN               NaN
# 2236558        99.0        NaN          NaN             NaN               NaN
# 2236567        99.0        NaN          NaN             NaN               NaN
# 2236918        99.0        NaN          NaN             NaN               NaN
# 2236951        99.0        NaN          NaN             NaN               NaN
#
#          widget_id  ... index2  error_type filename save_copy cmd_line  \
# 90             NaN  ...    NaN         NaN      NaN       NaN      NaN
# 126            NaN  ...    NaN         NaN      NaN       NaN      NaN
# 159            NaN  ...    NaN         NaN      NaN       NaN      NaN
# 178            NaN  ...    NaN         NaN      NaN       NaN      NaN
# 246            NaN  ...    NaN         NaN      NaN       NaN      NaN
# ...            ...  ...    ...         ...      ...       ...      ...
# 2236463        NaN  ...    NaN         NaN      NaN       NaN      NaN
# 2236558        NaN  ...    NaN         NaN      NaN       NaN      NaN
# 2236567        NaN  ...    NaN         NaN      NaN       NaN      NaN
# 2236918        NaN  ...    NaN         NaN      NaN       NaN      NaN
# 2236951        NaN  ...    NaN         NaN      NaN       NaN      NaN
#
#                 command_text input_text  widget command_id denied
# 90          %Run turtle.py\n        NaN     NaN        NaN    NaN
# 126         %Run turtle.py\n        NaN     NaN        NaN    NaN
# 159      %Run tartaruga.py\n        NaN     NaN        NaN    NaN
# 178      %Run tartaruga.py\n        NaN     NaN        NaN    NaN
# 246          %Run tarta.py\n        NaN     NaN        NaN    NaN
# ...                      ...        ...     ...        ...    ...
# 2236463    %Run Lab14_1.py\n        NaN     NaN        NaN    NaN
# 2236558    %Run Lab14_1.py\n        NaN     NaN        NaN    NaN
# 2236567    %Run Lab14_1.py\n        NaN     NaN        NaN    NaN
# 2236918    %Run Lab14_1.py\n        NaN     NaN        NaN    NaN
# 2236951    %Run Lab14_1.py\n        NaN     NaN        NaN    NaN
#
# [20357 rows x 28 columns]

# %%
plt.figure(figsize=(30, 10))
sns.countplot('student_ID', data=df_run, palette="pastel", edgecolor=".3")

plt.xlabel("Students")
plt.ylabel("Number of Run")
plt.show()

# %% [markdown]
# Mean of run per student

# %%
#Mean of run per student
df_run.groupby(['student_ID'])['command_text'].count().mean()
# Out:
# 209.43010752688173

# %% [markdown]
# # Pasted text

# %%
df_sequence_paste= df[df['sequence'].notna()]

df_paste = df_sequence_paste[df_sequence_paste['sequence'].str.contains("<<Paste>>")]

# %%
df_paste
# Out:
#         view_id view_class   sequence                       time  student_ID  \
# 2104        NaN        NaN  <<Paste>> 2020-03-23 15:27:13.480797         1.0
# 2298        NaN        NaN  <<Paste>> 2020-03-23 15:30:17.190550         1.0
# 3516        NaN        NaN  <<Paste>> 2020-03-23 16:29:17.360904         1.0
# 3804        NaN        NaN  <<Paste>> 2020-03-23 16:35:07.833767         1.0
# 3949        NaN        NaN  <<Paste>> 2020-03-23 16:41:10.629713         1.0
# ...         ...        ...        ...                        ...         ...
# 2235128     NaN        NaN  <<Paste>> 2020-05-14 15:29:52.944451        99.0
# 2235327     NaN        NaN  <<Paste>> 2020-05-14 15:32:19.641842        99.0
# 2235765     NaN        NaN  <<Paste>> 2020-05-14 15:41:02.653756        99.0
# 2236391     NaN        NaN  <<Paste>> 2020-05-14 15:53:15.062648        99.0
# 2236911     NaN        NaN  <<Paste>> 2020-05-14 15:59:19.417487        99.0
#
#          editor_id editor_class  text_widget_id text_widget_class   widget_id  \
# 2104           NaN          NaN      54768912.0         ShellText  54768912.0
# 2298           NaN          NaN      54768912.0         ShellText  54768912.0
# 3516           NaN          NaN      64777680.0         ShellText  64777680.0
# 3804           NaN          NaN      64777680.0         ShellText  64777680.0
# 3949           NaN          NaN      64777680.0         ShellText  64777680.0
# ...            ...          ...             ...               ...         ...
# 2235128        NaN          NaN      63131248.0      CodeViewText  63131248.0
# 2235327        NaN          NaN      63131248.0      CodeViewText  63131248.0
# 2235765        NaN          NaN      63131248.0      CodeViewText  63131248.0
# 2236391        NaN          NaN      63131248.0      CodeViewText  63131248.0
# 2236911        NaN          NaN      63131248.0      CodeViewText  63131248.0
#
#          ... index2  error_type filename save_copy cmd_line command_text  \
# 2104     ...    NaN         NaN      NaN       NaN      NaN          NaN
# 2298     ...    NaN         NaN      NaN       NaN      NaN          NaN
# 3516     ...    NaN         NaN      NaN       NaN      NaN          NaN
# 3804     ...    NaN         NaN      NaN       NaN      NaN          NaN
# 3949     ...    NaN         NaN      NaN       NaN      NaN          NaN
# ...      ...    ...         ...      ...       ...      ...          ...
# 2235128  ...    NaN         NaN      NaN       NaN      NaN          NaN
# 2235327  ...    NaN         NaN      NaN       NaN      NaN          NaN
# 2235765  ...    NaN         NaN      NaN       NaN      NaN          NaN
# 2236391  ...    NaN         NaN      NaN       NaN      NaN          NaN
# 2236911  ...    NaN         NaN      NaN       NaN      NaN          NaN
#
#         input_text  widget command_id denied
# 2104           NaN     NaN        NaN    NaN
# 2298           NaN     NaN        NaN    NaN
# 3516           NaN     NaN        NaN    NaN
# 3804           NaN     NaN        NaN    NaN
# 3949           NaN     NaN        NaN    NaN
# ...            ...     ...        ...    ...
# 2235128        NaN     NaN        NaN    NaN
# 2235327        NaN     NaN        NaN    NaN
# 2235765        NaN     NaN        NaN    NaN
# 2236391        NaN     NaN        NaN    NaN
# 2236911        NaN     NaN        NaN    NaN
#
# [8161 rows x 28 columns]

# %%
plt.figure(figsize=(30, 10))
sns.countplot('student_ID', data=df_paste, palette="pastel", edgecolor=".3")

plt.xlabel("Students")
plt.ylabel("Number of Paste")
plt.show()

# %% [markdown]
# Mean of text pasted per student

# %%
df_paste.groupby(['student_ID'])['sequence'].count().mean()
# Out:
# 209.43010752688173
