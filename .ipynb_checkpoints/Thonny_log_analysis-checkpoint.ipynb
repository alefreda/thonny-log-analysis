# %%
import numpy as np
import pandas as pd

# Visualization
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.pyplot import pie, axis, show

import seaborn as sns # For mathematical calculations
import matplotlib.pyplot as plt  # For plotting graphs
from datetime import datetime    # To access datetime

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_csv('dataset_thonny_logs.csv')
# Out:
# c:\users\alexf\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (22,25,26,27,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
def display_all(df):
    with pd.option_context("display.max_row", 100, "display.max_columns", 100):
        display(df)
display_all(df.head())
# Out:
#          view_id     view_class           sequence  \
# 0      ShellView      ShellView           ShowView
# 1  AssistantView  AssistantView           ShowView
# 2            NaN            NaN  EditorTextCreated
# 3            NaN            NaN            NewFile
# 4      ShellView      ShellView           ShowView
#
#                          time  student_ID  target   editor_id editor_class  \
# 0  2020-03-23T14:33:24.525803         1.0     0.0         NaN          NaN
# 1  2020-03-23T14:33:24.543817         1.0     0.0         NaN          NaN
# 2  2020-03-23T14:33:24.578842         1.0     0.0  75874928.0       Editor
# 3  2020-03-23T14:33:24.579842         1.0     0.0  75874928.0       Editor
# 4  2020-03-23T14:33:24.579842         1.0     0.0         NaN          NaN
#
#    text_widget_id text_widget_class  widget_id widget_class  index text tags  \
# 0             NaN               NaN        NaN          NaN    NaN  NaN  NaN
# 1             NaN               NaN        NaN          NaN    NaN  NaN  NaN
# 2      75874448.0      CodeViewText        NaN          NaN    NaN  NaN  NaN
# 3      75874448.0      CodeViewText        NaN          NaN    NaN  NaN  NaN
# 4             NaN               NaN        NaN          NaN    NaN  NaN  NaN
#
#   trivial_for_coloring trivial_for_parens text_widget_context  index1 index2  \
# 0                  NaN                NaN                 NaN     NaN    NaN
# 1                  NaN                NaN                 NaN     NaN    NaN
# 2                  NaN                NaN                 NaN     NaN    NaN
# 3                  NaN                NaN                 NaN     NaN    NaN
# 4                  NaN                NaN                 NaN     NaN    NaN
#
#   error_type filename save_copy cmd_line command_text input_text widget  \
# 0        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 1        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 2        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 3        NaN      NaN       NaN      NaN          NaN        NaN    NaN
# 4        NaN      NaN       NaN      NaN          NaN        NaN    NaN
#
#   command_id denied
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN

# %%
df.describe().T
# Out:
#                     count          mean           std        min          25%  \
# student_ID      2109852.0  5.675441e+01  3.104495e+01        1.0        29.00
# target          2109852.0  4.556405e-01  4.980285e-01        0.0         0.00
# editor_id         26153.0  2.567327e+12  1.878893e+13  1598960.0  70066608.00
# text_widget_id  1910292.0  2.603825e+12  1.891882e+13  1597616.0  70691728.00
# widget_id        312544.0  1.652807e+12  1.512510e+13  1597616.0  56461008.00
# index           1505967.0  1.030906e+03  1.749690e+03        1.0         9.19
# index1           258805.0  4.994501e+01  2.558476e+02        1.0         5.90
#
#                         50%          75%           max
# student_ID            61.00         84.0  1.060000e+02
# target                 0.00          1.0  1.000000e+00
# editor_id       81101104.00  137319536.0  1.406988e+14
# text_widget_id  80011504.00  158518640.0  1.406988e+14
# widget_id       73523248.00   94934544.0  1.406989e+14
# index                 38.00       1460.0  6.981000e+03
# index1                13.13         34.0  6.812000e+03

# %% [markdown]
# # Information about Missing values

# %%
msno.matrix(df)
plt.show()

# %%
msno.bar(df,sort='descending',color='#33A1FF')
plt.show()

# %%
def Missing_Values(df):
    variable_name = []
    total_value = []
    total_missing_value = []
    missing_value_rate = []
    unique_value_list = []
    total_unique_value = []
    data_type = []
    
    for col in df.columns:
        variable_name.append(col)
        data_type.append(df[col].dtype)
        total_value.append(df[col].shape[0])
        total_missing_value.append(df[col].isnull().sum())
        missing_value_rate.append(round(df[col].isnull().sum()/df[col].shape[0],4))


        
    missing_data=pd.DataFrame({"Variable":variable_name,\
                               "Total_Value":total_value,\
                               "Total_Missing_Value":total_missing_value,\
                               "%_Missing_Value_Rate":missing_value_rate,\
                               "Data_Type":data_type\

                              })
    
    missing_data = missing_data.set_index("Variable")
    return missing_data.sort_values("Total_Missing_Value",ascending=False)

dataframe_info = Missing_Values(df)
dataframe_info
# Out:
#                       Total_Value  Total_Missing_Value  %_Missing_Value_Rate  \
# Variable
# denied                    2173390              2173381                1.0000
# command_id                2173390              2173381                1.0000
# widget                    2173390              2173292                1.0000
# save_copy                 2173390              2171868                0.9993
# input_text                2173390              2166851                0.9970
# error_type                2173390              2166099                0.9966
# view_class                2173390              2160601                0.9941
# view_id                   2173390              2160601                0.9941
# cmd_line                  2173390              2152281                0.9903
# filename                  2173390              2152084                0.9902
# editor_class              2173390              2147237                0.9880
# editor_id                 2173390              2147237                0.9880
# command_text              2173390              2144013                0.9865
# index1                    2173390              1914585                0.8809
# index2                    2173390              1914585                0.8809
# widget_id                 2173390              1860846                0.8562
# widget_class              2173390              1860846                0.8562
# text_widget_context       2173390              1314652                0.6049
# text                      2173390               677130                0.3116
# tags                      2173390               667423                0.3071
# index                     2173390               667423                0.3071
# trivial_for_parens        2173390               439963                0.2024
# trivial_for_coloring      2173390               439963                0.2024
# text_widget_class         2173390               263098                0.1211
# text_widget_id            2173390               263098                0.1211
# target                    2173390                63538                0.0292
# student_ID                2173390                63538                0.0292
# time                      2173390                    0                0.0000
# sequence                  2173390                    0                0.0000
#
#                      Data_Type
# Variable
# denied                  object
# command_id              object
# widget                  object
# save_copy               object
# input_text              object
# error_type              object
# view_class              object
# view_id                 object
# cmd_line                object
# filename                object
# editor_class            object
# editor_id              float64
# command_text            object
# index1                 float64
# index2                  object
# widget_id              float64
# widget_class            object
# text_widget_context     object
# text                    object
# tags                    object
# index                  float64
# trivial_for_parens      object
# trivial_for_coloring    object
# text_widget_class       object
# text_widget_id         float64
# target                 float64
# student_ID             float64
# time                    object
# sequence                object

# %% [markdown]
# Heatmap

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['denied','command_id', 'widget'])
# Out:
#                view_id     view_class           sequence  \
# 0            ShellView      ShellView           ShowView
# 1        AssistantView  AssistantView           ShowView
# 2                  NaN            NaN  EditorTextCreated
# 3                  NaN            NaN            NewFile
# 4            ShellView      ShellView           ShowView
# ...                ...            ...                ...
# 2173385            NaN            NaN         TextInsert
# 2173386            NaN            NaN         <FocusOut>
# 2173387            NaN            NaN          <FocusIn>
# 2173388            NaN            NaN         <Button-1>
# 2173389            NaN            NaN         <Button-1>
#
#                                time  student_ID  target   editor_id  \
# 0        2020-03-23T14:33:24.525803         1.0     0.0         NaN
# 1        2020-03-23T14:33:24.543817         1.0     0.0         NaN
# 2        2020-03-23T14:33:24.578842         1.0     0.0  75874928.0
# 3        2020-03-23T14:33:24.579842         1.0     0.0  75874928.0
# 4        2020-03-23T14:33:24.579842         1.0     0.0         NaN
# ...                             ...         ...     ...         ...
# 2173385  2020-05-14T15:59:38.295567        99.0     1.0         NaN
# 2173386  2020-05-14T15:59:39.585641        99.0     1.0         NaN
# 2173387  2020-05-14T16:00:44.554357        99.0     1.0         NaN
# 2173388  2020-05-14T16:00:48.339574        99.0     1.0         NaN
# 2173389  2020-05-14T16:00:49.563644        99.0     1.0         NaN
#
#         editor_class  text_widget_id text_widget_class  ...  \
# 0                NaN             NaN               NaN  ...
# 1                NaN             NaN               NaN  ...
# 2             Editor      75874448.0      CodeViewText  ...
# 3             Editor      75874448.0      CodeViewText  ...
# 4                NaN             NaN               NaN  ...
# ...              ...             ...               ...  ...
# 2173385          NaN      62161040.0         ShellText  ...
# 2173386          NaN             NaN               NaN  ...
# 2173387          NaN             NaN               NaN  ...
# 2173388          NaN             NaN               NaN  ...
# 2173389          NaN             NaN               NaN  ...
#
#          trivial_for_parens text_widget_context  index1 index2 error_type  \
# 0                       NaN                 NaN     NaN    NaN        NaN
# 1                       NaN                 NaN     NaN    NaN        NaN
# 2                       NaN                 NaN     NaN    NaN        NaN
# 3                       NaN                 NaN     NaN    NaN        NaN
# 4                       NaN                 NaN     NaN    NaN        NaN
# ...                     ...                 ...     ...    ...        ...
# 2173385               False               shell     NaN    NaN        NaN
# 2173386                 NaN                 NaN     NaN    NaN        NaN
# 2173387                 NaN                 NaN     NaN    NaN        NaN
# 2173388                 NaN                 NaN     NaN    NaN        NaN
# 2173389                 NaN                 NaN     NaN    NaN        NaN
#
#         filename save_copy cmd_line  command_text input_text
# 0            NaN       NaN      NaN           NaN        NaN
# 1            NaN       NaN      NaN           NaN        NaN
# 2            NaN       NaN      NaN           NaN        NaN
# 3            NaN       NaN      NaN           NaN        NaN
# 4            NaN       NaN      NaN           NaN        NaN
# ...          ...       ...      ...           ...        ...
# 2173385      NaN       NaN      NaN           NaN        NaN
# 2173386      NaN       NaN      NaN           NaN        NaN
# 2173387      NaN       NaN      NaN           NaN        NaN
# 2173388      NaN       NaN      NaN           NaN        NaN
# 2173389      NaN       NaN      NaN           NaN        NaN
#
# [2173390 rows x 26 columns]

# %% [markdown]
# # Datetime

# %%
df['time'] = pd.to_datetime(df['time'])

# %% [markdown]
# # Errors

# %%
df_errors = df[df['error_type'].notna()]
#df_errors = df[df['text'].str.contains("Error", na=False)]
display_all(df_errors.head())
# Out:
#     view_id view_class    sequence                       time  student_ID  \
# 20      NaN        NaN  TextInsert 2020-03-23 14:33:52.646012         1.0
# 101     NaN        NaN  TextInsert 2020-03-23 14:38:45.693829         1.0
# 137     NaN        NaN  TextInsert 2020-03-23 14:39:53.491679         1.0
# 170     NaN        NaN  TextInsert 2020-03-23 14:41:16.309866         1.0
# 189     NaN        NaN  TextInsert 2020-03-23 14:41:29.322084         1.0
#
#      target  editor_id editor_class  text_widget_id text_widget_class  \
# 20      0.0        NaN          NaN      78015664.0     BaseShellText
# 101     0.0        NaN          NaN      54768912.0         ShellText
# 137     0.0        NaN          NaN      54768912.0         ShellText
# 170     0.0        NaN          NaN      54768912.0         ShellText
# 189     0.0        NaN          NaN      54768912.0         ShellText
#
#      widget_id widget_class  index  \
# 20         NaN          NaN    4.0
# 101        NaN          NaN    8.0
# 137        NaN          NaN   15.0
# 170        NaN          NaN   22.0
# 189        NaN          NaN    7.0
#
#                                                   text              tags  \
# 20   ValueError: invalid literal for int() with bas...  ('io', 'stderr')
# 101         NameError: name 'forward' is not defined\n  ('io', 'stderr')
# 137         NameError: name 'forward' is not defined\n  ('io', 'stderr')
# 170         NameError: name 'forward' is not defined\n  ('io', 'stderr')
# 189         NameError: name 'forward' is not defined\n  ('io', 'stderr')
#
#     trivial_for_coloring trivial_for_parens text_widget_context  index1  \
# 20                 False              False                 NaN     NaN
# 101                False              False               shell     NaN
# 137                False              False               shell     NaN
# 170                False              False               shell     NaN
# 189                False              False               shell     NaN
#
#     index2  error_type filename save_copy cmd_line command_text input_text  \
# 20     NaN  ValueError      NaN       NaN      NaN          NaN        NaN
# 101    NaN   NameError      NaN       NaN      NaN          NaN        NaN
# 137    NaN   NameError      NaN       NaN      NaN          NaN        NaN
# 170    NaN   NameError      NaN       NaN      NaN          NaN        NaN
# 189    NaN   NameError      NaN       NaN      NaN          NaN        NaN
#
#     widget command_id denied
# 20     NaN        NaN    NaN
# 101    NaN        NaN    NaN
# 137    NaN        NaN    NaN
# 170    NaN        NaN    NaN
# 189    NaN        NaN    NaN

# %%
df_errors.shape
# Out:
# (7291, 29)

# %% [markdown]
# Print number of errors during the laboratory lessons grouped by the months

# %%
#as string
df_errors['error_type'].astype(str)
# Out:
# 20             ValueError
# 101             NameError
# 137             NameError
# 170             NameError
# 189             NameError
#                 ...
# 2171837       SyntaxError
# 2172084       SyntaxError
# 2172131         TypeError
# 2172428    AttributeError
# 2172930    AttributeError
# Name: error_type, Length: 7291, dtype: object

# %% [markdown]
# Errors data cleaning

# %%
#df['prod_type'] = df['prod_type'].replace({'respon':'responsive', 'r':'responsive'})




df.drop(index=df[df['error_type'] == 'd={1'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Errore'].index, inplace=True)
df.drop(index=df[df['error_type'] == '    raise LookupError()'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'def reverse_lookup(d, v)'].index, inplace=True)
df.drop(index=df[df['error_type'] == '## turtle.py'].index, inplace=True)

df.drop(index=df[df['error_type'] == "%Run 'Lab_07 RangeError.py'"].index, inplace=True)

df.drop(index=df[df['error_type'] == 'Help on built-in function remove'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class list in module builtins'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class range in module builtins'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class str in module builtins'].index, inplace=True)



#df.drop(index=df[df['error_type'].str.contains("raise")].index, inplace=True)

#df.drop(df['error_type'].str.contains(r'[Lookup]').index)


new_df_errors = df[df['error_type'].notna()]

# %%
fig, axs = plt.subplots(figsize=(12, 4))
new_df_errors.groupby(new_df_errors["time"].dt.month)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Month")
plt.ylabel("Number of Errors")
# Out:
# Text(0, 0.5, 'Number of Errors')

# %%
df_grouped_month = new_df_errors.groupby(df_errors["time"].dt.month)

for group_name, df_group in df_grouped_month:
    fig, axs = plt.subplots(figsize=(12, 4))
    df_group.groupby(df_group["time"].dt.day)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
    plt.xlabel("Days of the month "+str(group_name))
    plt.ylabel("Number of Errors")

# %%
new_df_errors.groupby(['error_type']).groups.keys()
# Out:
# dict_keys(['AssertionError', 'AttributeError', 'FileNotFoundError', 'ImportError', 'IndentationError', 'IndexError', 'KeyError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'RecursionError', 'SyntaxError', 'TabError', 'TypeError', 'UnboundLocalError', 'ValueError', 'ZeroDivisionError', '_tkinter.TclError', 'turtle.TurtleGraphicsError'])

# %%
plt.figure(figsize=(20, 10))
new_df_errors.groupby(['error_type'])['error_type'].count().plot(kind='barh') 
plt.xlabel("Number of Errors")
plt.ylabel("Error type")
# Out:
# Text(0, 0.5, 'Error type')

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x=new_df_errors['error_type'], data=new_df_errors, palette="pastel", edgecolor=".3")

plt.show()

# %% [markdown]
# Mean of errors per student

# %%
#Mean of errors per student
new_df_errors.groupby(['student_ID'])['error_type'].count().mean()
# Out:
# 78.20430107526882

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x="error_type", hue="target", data=df, palette="YlOrBr")
plt.show()

# %% [markdown]
# # Numer of Run

# %%
#df with Run 

df_command_text= df[df['command_text'].notna()]

df_run = df_command_text[df_command_text['command_text'].str.contains("%Run")]

#df_run.groupby(['student_ID'])['command_text'].count()

# %%
df_run
# Out:
#         view_id view_class      sequence                       time  \
# 90          NaN        NaN  ShellCommand 2020-03-23 14:38:44.843547
# 126         NaN        NaN  ShellCommand 2020-03-23 14:39:53.154439
# 159         NaN        NaN  ShellCommand 2020-03-23 14:41:15.973628
# 178         NaN        NaN  ShellCommand 2020-03-23 14:41:28.986765
# 246         NaN        NaN  ShellCommand 2020-03-23 14:42:48.519844
# ...         ...        ...           ...                        ...
# 2172884     NaN        NaN  ShellCommand 2020-05-14 15:55:45.011224
# 2172979     NaN        NaN  ShellCommand 2020-05-14 15:56:25.143520
# 2172988     NaN        NaN  ShellCommand 2020-05-14 15:56:28.485711
# 2173339     NaN        NaN  ShellCommand 2020-05-14 15:59:20.885571
# 2173372     NaN        NaN  ShellCommand 2020-05-14 15:59:35.612414
#
#          student_ID  target  editor_id editor_class  text_widget_id  \
# 90              1.0     0.0        NaN          NaN             NaN
# 126             1.0     0.0        NaN          NaN             NaN
# 159             1.0     0.0        NaN          NaN             NaN
# 178             1.0     0.0        NaN          NaN             NaN
# 246             1.0     0.0        NaN          NaN             NaN
# ...             ...     ...        ...          ...             ...
# 2172884        99.0     1.0        NaN          NaN             NaN
# 2172979        99.0     1.0        NaN          NaN             NaN
# 2172988        99.0     1.0        NaN          NaN             NaN
# 2173339        99.0     1.0        NaN          NaN             NaN
# 2173372        99.0     1.0        NaN          NaN             NaN
#
#         text_widget_class  ...  index2 error_type  filename save_copy  \
# 90                    NaN  ...     NaN        NaN       NaN       NaN
# 126                   NaN  ...     NaN        NaN       NaN       NaN
# 159                   NaN  ...     NaN        NaN       NaN       NaN
# 178                   NaN  ...     NaN        NaN       NaN       NaN
# 246                   NaN  ...     NaN        NaN       NaN       NaN
# ...                   ...  ...     ...        ...       ...       ...
# 2172884               NaN  ...     NaN        NaN       NaN       NaN
# 2172979               NaN  ...     NaN        NaN       NaN       NaN
# 2172988               NaN  ...     NaN        NaN       NaN       NaN
# 2173339               NaN  ...     NaN        NaN       NaN       NaN
# 2173372               NaN  ...     NaN        NaN       NaN       NaN
#
#         cmd_line         command_text input_text widget  command_id denied
# 90           NaN     %Run turtle.py\n        NaN    NaN         NaN    NaN
# 126          NaN     %Run turtle.py\n        NaN    NaN         NaN    NaN
# 159          NaN  %Run tartaruga.py\n        NaN    NaN         NaN    NaN
# 178          NaN  %Run tartaruga.py\n        NaN    NaN         NaN    NaN
# 246          NaN      %Run tarta.py\n        NaN    NaN         NaN    NaN
# ...          ...                  ...        ...    ...         ...    ...
# 2172884      NaN    %Run Lab14_1.py\n        NaN    NaN         NaN    NaN
# 2172979      NaN    %Run Lab14_1.py\n        NaN    NaN         NaN    NaN
# 2172988      NaN    %Run Lab14_1.py\n        NaN    NaN         NaN    NaN
# 2173339      NaN    %Run Lab14_1.py\n        NaN    NaN         NaN    NaN
# 2173372      NaN    %Run Lab14_1.py\n        NaN    NaN         NaN    NaN
#
# [19934 rows x 29 columns]

# %%
plt.figure(figsize=(30, 10))
sns.countplot('student_ID', data=df_run, palette="pastel", edgecolor=".3")

plt.xlabel("Students")
plt.ylabel("Number of Run")
plt.show()

# %% [markdown]
# Mean of run per student

# %%
#Mean of run per student
df_run.groupby(['student_ID'])['command_text'].count().mean()
# Out:
# 209.43010752688173

# %% [markdown]
# # Pasted text

# %%
df_sequence_paste= df[df['sequence'].notna()]

df_paste = df_sequence_paste[df_sequence_paste['sequence'].str.contains("<<Paste>>")]

# %%
df_paste
# Out:
#         view_id view_class   sequence                       time  student_ID  \
# 2104        NaN        NaN  <<Paste>> 2020-03-23 15:27:13.480797         1.0
# 2298        NaN        NaN  <<Paste>> 2020-03-23 15:30:17.190550         1.0
# 3516        NaN        NaN  <<Paste>> 2020-03-23 16:29:17.360904         1.0
# 3804        NaN        NaN  <<Paste>> 2020-03-23 16:35:07.833767         1.0
# 3949        NaN        NaN  <<Paste>> 2020-03-23 16:41:10.629713         1.0
# ...         ...        ...        ...                        ...         ...
# 2171549     NaN        NaN  <<Paste>> 2020-05-14 15:29:52.944451        99.0
# 2171748     NaN        NaN  <<Paste>> 2020-05-14 15:32:19.641842        99.0
# 2172186     NaN        NaN  <<Paste>> 2020-05-14 15:41:02.653756        99.0
# 2172812     NaN        NaN  <<Paste>> 2020-05-14 15:53:15.062648        99.0
# 2173332     NaN        NaN  <<Paste>> 2020-05-14 15:59:19.417487        99.0
#
#          target  editor_id editor_class  text_widget_id text_widget_class  \
# 2104        0.0        NaN          NaN      54768912.0         ShellText
# 2298        0.0        NaN          NaN      54768912.0         ShellText
# 3516        0.0        NaN          NaN      64777680.0         ShellText
# 3804        0.0        NaN          NaN      64777680.0         ShellText
# 3949        0.0        NaN          NaN      64777680.0         ShellText
# ...         ...        ...          ...             ...               ...
# 2171549     1.0        NaN          NaN      63131248.0      CodeViewText
# 2171748     1.0        NaN          NaN      63131248.0      CodeViewText
# 2172186     1.0        NaN          NaN      63131248.0      CodeViewText
# 2172812     1.0        NaN          NaN      63131248.0      CodeViewText
# 2173332     1.0        NaN          NaN      63131248.0      CodeViewText
#
#          ...  index2 error_type  filename save_copy cmd_line command_text  \
# 2104     ...     NaN        NaN       NaN       NaN      NaN          NaN
# 2298     ...     NaN        NaN       NaN       NaN      NaN          NaN
# 3516     ...     NaN        NaN       NaN       NaN      NaN          NaN
# 3804     ...     NaN        NaN       NaN       NaN      NaN          NaN
# 3949     ...     NaN        NaN       NaN       NaN      NaN          NaN
# ...      ...     ...        ...       ...       ...      ...          ...
# 2171549  ...     NaN        NaN       NaN       NaN      NaN          NaN
# 2171748  ...     NaN        NaN       NaN       NaN      NaN          NaN
# 2172186  ...     NaN        NaN       NaN       NaN      NaN          NaN
# 2172812  ...     NaN        NaN       NaN       NaN      NaN          NaN
# 2173332  ...     NaN        NaN       NaN       NaN      NaN          NaN
#
#         input_text widget  command_id denied
# 2104           NaN    NaN         NaN    NaN
# 2298           NaN    NaN         NaN    NaN
# 3516           NaN    NaN         NaN    NaN
# 3804           NaN    NaN         NaN    NaN
# 3949           NaN    NaN         NaN    NaN
# ...            ...    ...         ...    ...
# 2171549        NaN    NaN         NaN    NaN
# 2171748        NaN    NaN         NaN    NaN
# 2172186        NaN    NaN         NaN    NaN
# 2172812        NaN    NaN         NaN    NaN
# 2173332        NaN    NaN         NaN    NaN
#
# [7832 rows x 29 columns]

# %%
plt.figure(figsize=(30, 10))
sns.countplot('student_ID', data=df_paste, palette="pastel", edgecolor=".3")

plt.xlabel("Students")
plt.ylabel("Number of Paste")
plt.show()

# %% [markdown]
# Mean of text pasted per student

# %%
df_paste.groupby(['student_ID'])['sequence'].count().mean()
# Out:
# 82.35164835164835
