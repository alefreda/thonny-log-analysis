# %%
import numpy as np
import pandas as pd

# Visualization
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.pyplot import pie, axis, show

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import math

import scipy.stats as ss
from collections import Counter
import itertools

from datetime import datetime    # To access datetime

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_csv('dataset_thonny_logs.csv') 


df_score_student_ID = pd.read_csv('id-log_voto.csv', sep=';')
# Out:
# c:\users\alexf\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (22,25,26,27,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
def display_all(df):
    with pd.option_context("display.max_row", 100, "display.max_columns", 100):
        display(df)
display_all(df.head())
# Out:
#          view_id     view_class           sequence  \
# 0      ShellView      ShellView           ShowView
# 1  AssistantView  AssistantView           ShowView
# 2            NaN            NaN  EditorTextCreated
# 3            NaN            NaN            NewFile
# 4      ShellView      ShellView           ShowView
#
#                          time  student_ID   score   editor_id editor_class  \
# 0  2020-03-23T14:33:24.525803           1  passed         NaN          NaN
# 1  2020-03-23T14:33:24.543817           1  passed         NaN          NaN
# 2  2020-03-23T14:33:24.578842           1  passed  75874928.0       Editor
# 3  2020-03-23T14:33:24.579842           1  passed  75874928.0       Editor
# 4  2020-03-23T14:33:24.579842           1  passed         NaN          NaN
#
#    text_widget_id text_widget_class  widget_id widget_class  index text tags  \
# 0             NaN               NaN        NaN          NaN    NaN  NaN  NaN
# ...

# %%
df.describe().T
# Out:
#                     count          mean           std        min         25%  \
# student_ID      2109852.0  5.675441e+01  3.104495e+01        1.0        29.0
# editor_id         25441.0  2.639104e+12  1.904507e+13  1598960.0  69954960.0
# text_widget_id  1867024.0  2.664113e+12  1.913259e+13  1597616.0  70588944.0
# widget_id        290403.0  1.778618e+12  1.568397e+13  1597616.0  55807184.0
# index           1474109.0  1.039818e+03  1.755312e+03        1.0         9.2
# index1           251750.0  5.023904e+01  2.589974e+02        1.0         5.9
#
#                         50%          75%           max
# student_ID            61.00         84.0  1.060000e+02
# editor_id       80989936.00  126304112.0  1.406988e+14
# text_widget_id  79953360.00  143695184.0  1.406988e+14
# widget_id       73061136.00   87054992.0  1.406989e+14
# index                 38.48       1491.0  6.981000e+03
# index1                13.11         34.0  6.812000e+03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2109852 entries, 0 to 2109851
# Data columns (total 29 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   view_id               object
#  1   view_class            object
#  2   sequence              object
#  3   time                  object
#  4   student_ID            int64
#  5   score                 object
#  6   editor_id             float64
#  7   editor_class          object
#  8   text_widget_id        float64
#  9   text_widget_class     object
#  10  widget_id             float64
#  11  widget_class          object
#  12  index                 float64
#  13  text                  object
#  14  tags                  object
#  15  trivial_for_coloring  object
#  16  trivial_for_parens    object
#  17  text_widget_context   object
#  18  index1                float64
#  19  index2                object
#  20  error_type            object
#  21  filename              object
# ...

# %% [markdown]
# # Information about Missing values

# %%
msno.matrix(df)
plt.show()

# %%
msno.bar(df,sort='descending',color='#33A1FF')
plt.show()

# %%
def Missing_Values(df):
    variable_name = []
    total_value = []
    total_missing_value = []
    missing_value_rate = []
    unique_value_list = []
    total_unique_value = []
    data_type = []
    
    for col in df.columns:
        variable_name.append(col)
        data_type.append(df[col].dtype)
        total_value.append(df[col].shape[0])
        total_missing_value.append(df[col].isnull().sum())
        missing_value_rate.append(round(df[col].isnull().sum()/df[col].shape[0],4))


        
    missing_data=pd.DataFrame({"Variable":variable_name,\
                               "Total_Value":total_value,\
                               "Total_Missing_Value":total_missing_value,\
                               "%_Missing_Value_Rate":missing_value_rate,\
                               "Data_Type":data_type\

                              })
    
    missing_data = missing_data.set_index("Variable")
    return missing_data.sort_values("Total_Missing_Value",ascending=False)

dataframe_info = Missing_Values(df)
dataframe_info
# Out:
#                       Total_Value  Total_Missing_Value  %_Missing_Value_Rate  \
# Variable
# denied                    2109852              2109843                1.0000
# command_id                2109852              2109843                1.0000
# widget                    2109852              2109754                1.0000
# save_copy                 2109852              2108389                0.9993
# input_text                2109852              2103329                0.9969
# error_type                2109852              2102561                0.9965
# view_class                2109852              2097479                0.9941
# view_id                   2109852              2097479                0.9941
# cmd_line                  2109852              2089270                0.9902
# filename                  2109852              2089095                0.9902
# editor_class              2109852              2084411                0.9879
# ...

# %% [markdown]
# Heatmap

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['denied','command_id', 'widget'])
# Out:
#                view_id     view_class           sequence  \
# 0            ShellView      ShellView           ShowView
# 1        AssistantView  AssistantView           ShowView
# 2                  NaN            NaN  EditorTextCreated
# 3                  NaN            NaN            NewFile
# 4            ShellView      ShellView           ShowView
# ...                ...            ...                ...
# 2109847            NaN            NaN         TextInsert
# 2109848            NaN            NaN         <FocusOut>
# 2109849            NaN            NaN          <FocusIn>
# 2109850            NaN            NaN         <Button-1>
# 2109851            NaN            NaN         <Button-1>
#
#                                time  student_ID      score   editor_id  \
# 0        2020-03-23T14:33:24.525803           1     passed         NaN
# 1        2020-03-23T14:33:24.543817           1     passed         NaN
# ...

# %% [markdown]
# # Datetime

# %%
df['time'] = pd.to_datetime(df['time'])

# %% [markdown]
# # Target distribution

# %% [markdown]
# target distribution by student

# %%
df_score_distribution_ID = df_score_student_ID.rename(columns={'Identificativo': 'student_ID', 'Voto verbalizzato' : 'score'})

df_score_distribution_ID["score"] = df_score_distribution_ID["score"].astype(pd.StringDtype())


df_score_distribution_ID.loc[df_score_distribution_ID['score'].str.contains('-'), 'score'] = '0'

df_score_distribution_ID["score"] = df_score_distribution_ID["score"].astype('int32')

# 0 = fail , 1 = pass, 2 = excellent

df_score_distribution_ID.loc[(df_score_distribution_ID['score'] >= 18) & (df_score_distribution_ID['score'] <= 26) , 'score'] = 1
df_score_distribution_ID.loc[df_score_distribution_ID['score'] > 26, 'score'] = 2

df_score_distribution_ID["score"] = df_score_distribution_ID["score"].astype(pd.StringDtype())

df_score_distribution_ID.loc[df_score_distribution_ID['score'].str.contains('0'), 'score'] = 'failed'
df_score_distribution_ID.loc[df_score_distribution_ID['score'].str.contains('1'), 'score'] = 'passed'
df_score_distribution_ID.loc[df_score_distribution_ID['score'].str.contains('2'), 'score'] = 'excellent'



fig, ax =plt.subplots(nrows=1,ncols=2, figsize=(12,5))

sns.countplot(x=df_score_distribution_ID['score'], data=df_score_distribution_ID, order = df_score_distribution_ID['score'].value_counts().index, palette="pastel",ax=ax[0], edgecolor=".3")

df_score_distribution_ID['score'].value_counts().plot.pie(autopct="%1.2f%%", ax=ax[1], colors=['#66a3ff','#facc99', '#FF0000'], 
                                        textprops={'fontsize': 12, 'color':'#0a0a00'})
plt.show()

# %% [markdown]
# target distribution by event

# %%
fig, ax =plt.subplots(nrows=1,ncols=2, figsize=(12,5))

sns.countplot(x=df['score'], data=df, order = df['score'].value_counts().index, palette="pastel",ax=ax[0], edgecolor=".3")

df['score'].value_counts().plot.pie(autopct="%1.2f%%", ax=ax[1], colors=['#66a3ff','#facc99', '#FF0000'], 
                                        textprops={'fontsize': 12, 'color':'#0a0a00'})
plt.show()

# %% [markdown]
# # Errors

# %%
df_errors = df[df['error_type'].notna()]
#df_errors = df[df['text'].str.contains("Error", na=False)]
display_all(df_errors.head())
# Out:
#     view_id view_class    sequence                       time  student_ID  \
# 20      NaN        NaN  TextInsert 2020-03-23 14:33:52.646012           1
# 101     NaN        NaN  TextInsert 2020-03-23 14:38:45.693829           1
# 137     NaN        NaN  TextInsert 2020-03-23 14:39:53.491679           1
# 170     NaN        NaN  TextInsert 2020-03-23 14:41:16.309866           1
# 189     NaN        NaN  TextInsert 2020-03-23 14:41:29.322084           1
#
#       score  editor_id editor_class  text_widget_id text_widget_class  \
# 20   passed        NaN          NaN      78015664.0     BaseShellText
# 101  passed        NaN          NaN      54768912.0         ShellText
# 137  passed        NaN          NaN      54768912.0         ShellText
# 170  passed        NaN          NaN      54768912.0         ShellText
# 189  passed        NaN          NaN      54768912.0         ShellText
#
#      widget_id widget_class  index  \
# 20         NaN          NaN    4.0
# ...

# %%
df_errors.shape
# Out:
# (7291, 29)

# %% [markdown]
# Print number of errors during the laboratory lessons grouped by the months

# %%
#as string
df_errors['error_type'].astype(str)
# Out:
# 20             ValueError
# 101             NameError
# 137             NameError
# 170             NameError
# 189             NameError
#                 ...
# 2108299       SyntaxError
# 2108546       SyntaxError
# 2108593         TypeError
# 2108890    AttributeError
# 2109392    AttributeError
# Name: error_type, Length: 7291, dtype: object

# %% [markdown]
# Errors data cleaning

# %%
#df['prod_type'] = df['prod_type'].replace({'respon':'responsive', 'r':'responsive'})




df.drop(index=df[df['error_type'] == 'd={1'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Errore'].index, inplace=True)
df.drop(index=df[df['error_type'] == '    raise LookupError()'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'def reverse_lookup(d, v)'].index, inplace=True)
df.drop(index=df[df['error_type'] == '## turtle.py'].index, inplace=True)

df.drop(index=df[df['error_type'] == "%Run 'Lab_07 RangeError.py'"].index, inplace=True)

df.drop(index=df[df['error_type'] == 'Help on built-in function remove'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class list in module builtins'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class range in module builtins'].index, inplace=True)
df.drop(index=df[df['error_type'] == 'Help on class str in module builtins'].index, inplace=True)



#df.drop(index=df[df['error_type'].str.contains("raise")].index, inplace=True)

#df.drop(df['error_type'].str.contains(r'[Lookup]').index)


new_df_errors = df[df['error_type'].notna()]

# %%
fig, axs = plt.subplots(figsize=(12, 4))
new_df_errors.groupby(new_df_errors["time"].dt.month)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Month")
plt.ylabel("Number of Errors")
# Out:
# Text(0, 0.5, 'Number of Errors')

# %%
df_grouped_month = new_df_errors.groupby(df_errors["time"].dt.month)

for group_name, df_group in df_grouped_month:
    fig, axs = plt.subplots(figsize=(12, 4))
    df_group.groupby(df_group["time"].dt.day)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
    plt.xlabel("Days of the month "+str(group_name))
    plt.ylabel("Number of Errors")

# %%
fig, axs = plt.subplots(figsize=(12, 4))
new_df_errors.groupby(new_df_errors["time"].dt.week)["error_type"].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Weeks")
plt.ylabel("Number of Errors")
# Out:
# Text(0, 0.5, 'Number of Errors')

# %%
new_df_errors.groupby(['error_type']).groups.keys()
# Out:
# dict_keys(['AssertionError', 'AttributeError', 'FileNotFoundError', 'ImportError', 'IndentationError', 'IndexError', 'KeyError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'RecursionError', 'SyntaxError', 'TabError', 'TypeError', 'UnboundLocalError', 'ValueError', 'ZeroDivisionError', '_tkinter.TclError', 'turtle.TurtleGraphicsError'])

# %%
plt.figure(figsize=(20, 10))
new_df_errors.groupby(['error_type'])['error_type'].count().plot(kind='barh') 

plt.xlabel("Number of Errors")
plt.ylabel("Error type")
# Out:
# Text(0, 0.5, 'Error type')

# %%
plt.figure(figsize=(30, 10))

sns.countplot(x=new_df_errors['error_type'], data=new_df_errors, palette="pastel", edgecolor=".3", order = new_df_errors['error_type'].value_counts().iloc[:7].index)

plt.show()

# %%
new_df_errors['error_type'].value_counts().plot.pie(autopct="%1.2f%%", 
                                        textprops={'fontsize': 13, 'color':'#0a0a00'})

plt.show()

# %% [markdown]
# Mean of errors per student

# %%
#Mean of errors per student
new_df_errors.groupby(['student_ID'])['error_type'].count().mean()
# Out:
# 78.20430107526882

# %% [markdown]
# Number of error by target

# %%
plt.figure(figsize=(30, 10))
hue_order = ['failed', 'passed', 'excellent']

sns.countplot(x="error_type", hue="score",hue_order=hue_order, data=new_df_errors, palette="YlOrBr_r", order = new_df_errors['error_type'].value_counts().iloc[:7].index)
plt.show()

# %%
# Distribution plots of Errors 
fig, (ax1,ax2) = plt.subplots(1, 2, figsize =(14,4))
plt.tight_layout()

sns.distplot(new_df_errors["time"].dt.month, 
             kde=False, 
             axlabel= 'Month', bins=3,
             hist_kws=dict(edgecolor='k',linewidth=1), color='teal', ax=ax1)
ax1.set_ylabel('Count')

ax1.set_title('Distribtuion of Errors, Months');

sns.distplot(new_df_errors["time"].dt.week, 
             kde=False, bins=12, 
             axlabel= 'Week',
             hist_kws=dict(edgecolor='k',linewidth=1), color='darkorange', ax=ax2)

ax2.set_title('Distribution of Errors, Weeks');

# %%
axes = new_df_errors.groupby([new_df_errors.time.values.astype('datetime64[W]'),'error_type']).error_type.count() \
                .sort_values(ascending=False).unstack().plot.line(marker='+',figsize=(18,4))
axes.set_title("Number or errors in time")
axes.set_xlabel("Weeks")
axes.set_ylabel("No. of Errors")
axes.legend(loc='upper right')
plt.show()
# Out:
# c:\users\alexf\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:613: UserWarning: The handle <matplotlib.lines.Line2D object at 0x000002A9536CAA60> has a label of '_tkinter.TclError' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %% [markdown]
# # Lab 7

# %%
plt.figure(figsize=(30, 10))

df_errors_lab7 = new_df_errors.loc[new_df_errors['time'].dt.date == pd.Timestamp(2020,3,30)]


plt.title("Lab 7")
#sns.countplot(x=new_df_errors['error_type'].loc[new_df_errors['time'].dt.date == pd.Timestamp(2020,3,30)], data=new_df_errors , palette="pastel", edgecolor=".3", order = new_df_errors['error_type'].value_counts().iloc[:7].index)


sns.countplot(x=df_errors_lab7['error_type'], data=df_errors_lab7 ,
              palette="pastel", edgecolor=".3", order = df_errors_lab7['error_type'].value_counts().iloc[:7].index)



plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.title("Lab 7")


hue_order = ['failed', 'passed', 'excellent']


sns.countplot(x="error_type", hue="score", data=df_errors_lab7, hue_order=hue_order, palette="YlOrBr_r", order = df_errors_lab7['error_type'].value_counts().iloc[:7].index)
plt.show()

# %% [markdown]
# # Lab 9

# %%
plt.figure(figsize=(30, 10))

df_errors_lab9 = new_df_errors.loc[new_df_errors['time'].dt.date == pd.Timestamp(2020,4,16)]


plt.title("Lab 9")

sns.countplot(x=df_errors_lab9['error_type'], data=df_errors_lab9 ,
              palette="pastel", edgecolor=".3", order = df_errors_lab9['error_type'].value_counts().iloc[:7].index)



plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.title("Lab 9")


hue_order = ['failed', 'passed', 'excellent']


sns.countplot(x="error_type", hue="score", data=df_errors_lab9, hue_order=hue_order, palette="YlOrBr_r", order = df_errors_lab9['error_type'].value_counts().iloc[:7].index)
plt.show()

# %%
df_errors_lab9_typeerror = df_errors_lab9.loc[df_errors_lab9['error_type'] == 'TypeError']
pd.options.display.max_rows = 999
pd.set_option('display.max_colwidth', None)
df_errors_lab9_typeerror[['text','student_ID','time']]
# Out:
#                                                                                                text  \
# 19183                             TypeError: unsupported operand type(s) for +: 'int' and 'tuple'\n
# 19240                             TypeError: unsupported operand type(s) for +: 'int' and 'tuple'\n
# 42772                     TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'\n
# 43666                          TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'\n
# 43706                          TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'\n
# 43763                          TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'\n
# 44682                            TypeError: minimo() takes 1 positional argument but 7 were given\n
# 44750                         TypeError: '<' not supported between instances of 'tuple' and 'int'\n
# ...

# %%
df_errors_lab9_typeerror.groupby(['text']).size().sort_values(ascending=False)
# Out:
# text
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'\n                     59
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'\n                          22
# TypeError: object of type 'int' has no len()\n                                                16
# TypeError: 'str' object does not support item assignment\n                                    11
# TypeError: '<' not supported between instances of 'int' and 'list'\n                          10
# TypeError: 'int' object is not iterable\n                                                      9
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'\n                           8
# TypeError: '<' not supported between instances of 'int' and 'NoneType'\n                       7
# TypeError: '<' not supported between instances of 'list' and 'int'\n                           7
# TypeError: '<' not supported between instances of 'int' and 'tuple'\n                          6
# ...

# %% [markdown]
# First exercise

# %%
#and (df_errors_lab9_typeerror['time'].dt.date < pd.Timestamp(2020,4,16 14:57:05))


#df_errors_lab9_typeerror_first = df_errors_lab9_typeerror.loc[df_errors_lab9_typeerror['time'].dt.date == pd.Timestamp(year = 2020, month = 4, day = 19, ) ]

df_errors_lab9_typeerror_first = df_errors_lab9_typeerror
#df_errors_lab9_typeerror_first.set_index('time')

df_errors_lab9_typeerror_first.index = pd.to_datetime(df_errors_lab9_typeerror_first['time'])

df_errors_lab9_typeerror_firstExercise = df_errors_lab9_typeerror_first.between_time('14:25:00', '14:55:00')

df_errors_lab9_typeerror_firstExercise[['text','student_ID','time']]

#typeerror frequenti
df_errors_lab9_typeerror_firstExercise.groupby(['text']).size().sort_values(ascending=False)
# Out:
# text
# TypeError: 'str' object does not support item assignment\n                   8
# TypeError: can only concatenate str (not "int") to str\n                     6
# TypeError: 'NoneType' object is not callable\n                               5
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'\n         5
# TypeError: 'str' object is not callable\n                                    3
# TypeError: string indices must be integers\n                                 2
# TypeError: unsupported operand type(s) for -: 'list' and 'int'\n             2
# TypeError: can only concatenate list (not "int") to list\n                   2
# TypeError: eval() arg 1 must be a string, bytes or code object\n             2
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'\n    2
# TypeError: unsupported operand type(s) for -: 'str' and 'str'\n              1
# TypeError: unsupported operand type(s) for +: 'bool' and 'str'\n             1
# ...

# %% [markdown]
# # Lab 12

# %%
plt.figure(figsize=(30, 10))

df_errors_lab12 = new_df_errors.loc[new_df_errors['time'].dt.date == pd.Timestamp(2020,5,7)]


plt.title("Lab 12")

sns.countplot(x=df_errors_lab12['error_type'], data=df_errors_lab12 ,
              palette="pastel", edgecolor=".3", order = df_errors_lab12['error_type'].value_counts().iloc[:7].index)



plt.show()

# %%
plt.figure(figsize=(30, 10))
plt.title("Lab 12")


hue_order = ['failed', 'passed', 'excellent']


sns.countplot(x="error_type", hue="score", data=df_errors_lab12, hue_order=hue_order, palette="YlOrBr_r", order = df_errors_lab12['error_type'].value_counts().iloc[:7].index)
plt.show()

# %% [markdown]
# Errors grouped by student

# %%
#errors_grouped_by_student = new_df_errors.groupby(['student_ID']).count()
errors_grouped_by_student = new_df_errors.groupby(['student_ID', 'error_type']).size().unstack(fill_value=0)


errors_grouped_by_student.drop('turtle.TurtleGraphicsError', axis=1, inplace=True)
errors_grouped_by_student.drop('MemoryError', axis=1, inplace=True)
errors_grouped_by_student.drop('FileNotFoundError', axis=1, inplace=True)
errors_grouped_by_student.drop('AssertionError', axis=1, inplace=True)
errors_grouped_by_student.drop('TabError', axis=1, inplace=True)

# %% [markdown]
# # Numer of Run

# %%
#df with Run 

df_command_text= df[df['command_text'].notna()]

df_run = df_command_text[df_command_text['command_text'].str.contains("%Run")]

#df_run.groupby(['student_ID'])['command_text'].count()

# %%
df_run
# Out:
#         view_id view_class      sequence                       time  \
# 90          NaN        NaN  ShellCommand 2020-03-23 14:38:44.843547
# 126         NaN        NaN  ShellCommand 2020-03-23 14:39:53.154439
# 159         NaN        NaN  ShellCommand 2020-03-23 14:41:15.973628
# 178         NaN        NaN  ShellCommand 2020-03-23 14:41:28.986765
# 246         NaN        NaN  ShellCommand 2020-03-23 14:42:48.519844
# ...         ...        ...           ...                        ...
# 2109346     NaN        NaN  ShellCommand 2020-05-14 15:55:45.011224
# 2109441     NaN        NaN  ShellCommand 2020-05-14 15:56:25.143520
# 2109450     NaN        NaN  ShellCommand 2020-05-14 15:56:28.485711
# 2109801     NaN        NaN  ShellCommand 2020-05-14 15:59:20.885571
# 2109834     NaN        NaN  ShellCommand 2020-05-14 15:59:35.612414
#
#          student_ID      score  editor_id editor_class  text_widget_id  \
# 90                1     passed        NaN          NaN             NaN
# ...

# %%
plt.figure(figsize=(30, 10))
sns.countplot('student_ID', data=df_run, palette="pastel", edgecolor=".3")

plt.xlabel("Students")
plt.ylabel("Number of Run")
plt.show()

# %% [markdown]
# Mean of run per student

# %%
#Mean of run per student
df_run.groupby(['student_ID'])['command_text'].count().mean()
# Out:
# 209.43010752688173

# %%
fig, axs = plt.subplots(figsize=(12, 4))
df_run.groupby(df_run["time"].dt.month)['command_text'].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Month")
plt.ylabel("Number of Run")
# Out:
# Text(0, 0.5, 'Number of Run')

# %%
df_grouped_month_run = df_run.groupby(df_run["time"].dt.month)

for group_name_run, df_group_run in df_grouped_month_run:

    fig, axs = plt.subplots(figsize=(12, 4))
    df_group_run.groupby(df_group_run["time"].dt.day)['command_text'].count().plot(kind='bar', rot=0, ax=axs)
    plt.xlabel("Days of the month "+str(group_name_run))
    plt.ylabel("Number of Run")

# %%
fig, axs = plt.subplots(figsize=(12, 4))
df_run.groupby(df_run["time"].dt.week)['command_text'].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Week")
plt.ylabel("Number of Run")
# Out:
# Text(0, 0.5, 'Number of Run')

# %% [markdown]
# # Pasted text

# %%
df_sequence_paste= df[df['sequence'].notna()]

df_paste = df_sequence_paste[df_sequence_paste['sequence'].str.contains("<<Paste>>")]

# %%
df_paste
# Out:
#         view_id view_class   sequence                       time  student_ID  \
# 2104        NaN        NaN  <<Paste>> 2020-03-23 15:27:13.480797           1
# 2298        NaN        NaN  <<Paste>> 2020-03-23 15:30:17.190550           1
# 3516        NaN        NaN  <<Paste>> 2020-03-23 16:29:17.360904           1
# 3804        NaN        NaN  <<Paste>> 2020-03-23 16:35:07.833767           1
# 3949        NaN        NaN  <<Paste>> 2020-03-23 16:41:10.629713           1
# ...         ...        ...        ...                        ...         ...
# 2108011     NaN        NaN  <<Paste>> 2020-05-14 15:29:52.944451          99
# 2108210     NaN        NaN  <<Paste>> 2020-05-14 15:32:19.641842          99
# 2108648     NaN        NaN  <<Paste>> 2020-05-14 15:41:02.653756          99
# 2109274     NaN        NaN  <<Paste>> 2020-05-14 15:53:15.062648          99
# 2109794     NaN        NaN  <<Paste>> 2020-05-14 15:59:19.417487          99
#
# ...

# %%
plt.figure(figsize=(30, 10))
sns.countplot('student_ID', data=df_paste, palette="pastel", edgecolor=".3")

plt.xlabel("Students")
plt.ylabel("Number of Paste")
plt.show()

# %% [markdown]
# Mean of text pasted per student

# %%
df_paste.groupby(['student_ID'])['sequence'].count().mean()
# Out:
# 82.35164835164835

# %%
fig, axs = plt.subplots(figsize=(12, 4))
df_paste.groupby(df_paste["time"].dt.month)['sequence'].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Month")
plt.ylabel("Number of Paste")
# Out:
# Text(0, 0.5, 'Number of Paste')

# %%
df_grouped_month_paste = df_paste.groupby(df_paste["time"].dt.month)

for group_name_paste, df_group_paste in df_grouped_month_paste:
    fig, axs = plt.subplots(figsize=(12, 4))
    df_group_paste.groupby(df_group_paste["time"].dt.day)['sequence'].count().plot(kind='bar', rot=0, ax=axs)
    plt.xlabel("Days of the month "+str(group_name_paste))
    plt.ylabel("Number of Paste")

# %%
fig, axs = plt.subplots(figsize=(12, 4))
df_paste.groupby(df_paste["time"].dt.week)['sequence'].count().plot(kind='bar', rot=0, ax=axs)
plt.xlabel("Week")
plt.ylabel("Number of Paste")
# Out:
# Text(0, 0.5, 'Number of Paste')

# %% [markdown]
# # Correlations

# %%
df.corr()
# Out:
#                 student_ID  editor_id  text_widget_id  widget_id     index  \
# student_ID        1.000000   0.098563        0.123127   0.094622 -0.097128
# editor_id         0.098563   1.000000        1.000000        NaN       NaN
# text_widget_id    0.123127   1.000000        1.000000   1.000000  0.052419
# widget_id         0.094622        NaN        1.000000   1.000000       NaN
# index            -0.097128        NaN        0.052419        NaN  1.000000
# index1            0.039681        NaN        0.236618        NaN       NaN
#
#                   index1
# student_ID      0.039681
# editor_id            NaN
# text_widget_id  0.236618
# widget_id            NaN
# index                NaN
# index1          1.000000

# %% [markdown]
# # Cramers V for categorial-categorial association

# %%
def cramers_v(confusion_matrix):
    """ 
    Calculate Cramers V statistic for categorial-categorial association.
    
    """
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

confusion_matrix = pd.crosstab(df["error_type"], df["score"]).values
cramers_v(confusion_matrix) # Class is highly associated to odor (Both categorical)
# Out:
# 0.07062125019028435

# %%
def find_association(method,data,columns):
    
    df = data
    cols = columns
    corrM = np.zeros((len(cols),len(cols)))
    np.fill_diagonal(corrM, 1)
    
    if method == "thiels_u":
        for col1, col2 in itertools.combinations(cols, 2):
            idx1, idx2 = cols.index(col1), cols.index(col2)
            corrM[idx1, idx2] = theils_u(df[col1], df[col2])
            corrM[idx2, idx1] = corrM[idx1, idx2]
        
    elif method == "cramers_v":
        
        for col1, col2 in itertools.combinations(cols, 2):
            idx1, idx2 = cols.index(col1), cols.index(col2)
            corrM[idx1, idx2] = cramers_v((pd.crosstab(df[col1], df[col2])).values)
            corrM[idx2, idx1] = corrM[idx1, idx2]

    corr = pd.DataFrame(corrM, index=cols, columns=cols)
    fig, ax = plt.subplots(figsize=(12, 12))
    ax = sns.heatmap(corr, annot=True, ax=ax); 
  
    ax.set_title("Correlation between Variables");

# %%
cols_1 = ['view_id', 'view_class', 'sequence', 'score']

# %%
find_association("cramers_v",df,cols_1)

# %% [markdown]
# # Theil’s U

# %%
def conditional_entropy(x, y):
    """
    Calculates the conditional entropy of x given y: S(x|y)
    Parameters
    ----------
    x : list / NumPy ndarray / Pandas Series
        A sequence of measurements
    y : list / NumPy ndarray / Pandas Series
        A sequence of measurements
    """
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x,y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0.0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y/p_xy)
    return entropy

# %%
def theils_u(x, y):
    s_xy = conditional_entropy(x,y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x

# %%
cols_2 = ['view_id', 'view_class', 'sequence', 'score', 'error_type', 'tags', 'text', 'student_ID', 'command_text']

# %%
find_association("thiels_u",df,cols_2)

# %% [markdown]
# # Grouped by students ID

# %%
errors_grouped_by_student
# Out:
# error_type  AttributeError  ImportError  IndentationError  IndexError  \
# student_ID
# 1                        0            1                 2           8
# 2                       12            0                 2           5
# 3                        0            0                 2           0
# 4                       12            0                 2           6
# 5                        0            0                 1           3
# 6                        0            0                 5           7
# 7                        0            0                 3           0
# 9                        1            0                 0           6
# 10                       2            0                 5          21
# 12                       6            1                14          16
# 13                      16            0                 5           2
# 14                       1            0                 0           0
# ...

# %%
paste_groupbystudent = df_paste.groupby(['student_ID'])['sequence'].count()

# %%
#Aggiungo colonna codice incollato

df_grouped_by_student = errors_grouped_by_student
df_grouped_by_student['Paste'] = paste_groupbystudent

#sostituisco nan con media 

mean_pasted = df_paste.groupby(['student_ID'])['sequence'].count().mean()
#print(mode_race)
df_grouped_by_student['Paste'].fillna(mean_pasted, inplace=True)



df_grouped_by_student['Paste'] = df_grouped_by_student['Paste'].astype(int)

df_grouped_by_student
# Out:
# error_type  AttributeError  ImportError  IndentationError  IndexError  \
# student_ID
# 1                        0            1                 2           8
# 2                       12            0                 2           5
# 3                        0            0                 2           0
# 4                       12            0                 2           6
# 5                        0            0                 1           3
# 6                        0            0                 5           7
# 7                        0            0                 3           0
# 9                        1            0                 0           6
# 10                       2            0                 5          21
# 12                       6            1                14          16
# 13                      16            0                 5           2
# 14                       1            0                 0           0
# ...

# %%
#Aggiungo colonna numero run 

run2_groupbystudent = df_run.groupby(['student_ID'])['command_text'].count()
df_grouped_by_student['Run'] = run2_groupbystudent
df_grouped_by_student
# Out:
# error_type  AttributeError  ImportError  IndentationError  IndexError  \
# student_ID
# 1                        0            1                 2           8
# 2                       12            0                 2           5
# 3                        0            0                 2           0
# 4                       12            0                 2           6
# 5                        0            0                 1           3
# 6                        0            0                 5           7
# 7                        0            0                 3           0
# 9                        1            0                 0           6
# 10                       2            0                 5          21
# 12                       6            1                14          16
# 13                      16            0                 5           2
# 14                       1            0                 0           0
# ...

# %%
#Aggiungo colonna score

#a = df.groupby(['student_ID'])['score']
#a.head()

df_grouped_by_student['Score'] = df_score_distribution_ID['score']

mode_score = df_grouped_by_student['Score'].mode()
#print(mode_race)
df_grouped_by_student['Score'].fillna(mode_score[0], inplace=True)


df_grouped_by_student
# Out:
# error_type  AttributeError  ImportError  IndentationError  IndexError  \
# student_ID
# 1                        0            1                 2           8
# 2                       12            0                 2           5
# 3                        0            0                 2           0
# 4                       12            0                 2           6
# 5                        0            0                 1           3
# 6                        0            0                 5           7
# 7                        0            0                 3           0
# 9                        1            0                 0           6
# 10                       2            0                 5          21
# 12                       6            1                14          16
# 13                      16            0                 5           2
# 14                       1            0                 0           0
# ...

# %%
#Numero di eventi

df_grouped_by_student['Events'] = df.groupby(['student_ID']).size()
df_grouped_by_student
# Out:
# error_type  AttributeError  ImportError  IndentationError  IndexError  \
# student_ID
# 1                        0            1                 2           8
# 2                       12            0                 2           5
# 3                        0            0                 2           0
# 4                       12            0                 2           6
# 5                        0            0                 1           3
# 6                        0            0                 5           7
# 7                        0            0                 3           0
# 9                        1            0                 0           6
# 10                       2            0                 5          21
# 12                       6            1                14          16
# 13                      16            0                 5           2
# 14                       1            0                 0           0
# ...

# %%
#Numero di errori 

df_grouped_by_student['Errors'] = new_df_errors.groupby(['student_ID'])['error_type'].count()

#df_grouped_by_student

# %% [markdown]
# # Dataset

# %%
#Standardizzazione
#scaler = StandardScaler()
scaler = MinMaxScaler()
#print(scaler.fit(df_grouped_by_student[['Errors']]))

#print(scaler.transform(df_grouped_by_student[['Errors']]))

for column in df_grouped_by_student:
    if (column != "Score"):
        df_grouped_by_student[column] = scaler.fit_transform(df_grouped_by_student[[column]])
    
df_grouped_by_student = pd.get_dummies(df_grouped_by_student, columns=['Score'])
df_grouped_by_student
# Out:
#             AttributeError  ImportError  IndentationError  IndexError  \
# student_ID
# 1                -0.871287     1.747285         -0.479885    0.481449
# 2                 0.802304    -0.509625         -0.479885   -0.069060
# 3                -0.871287    -0.509625         -0.479885   -0.986575
# 4                 0.802304    -0.509625         -0.479885    0.114443
# 5                -0.871287    -0.509625         -0.684607   -0.436066
# 6                -0.871287    -0.509625          0.134280    0.297946
# 7                -0.871287    -0.509625         -0.275164   -0.986575
# 9                -0.731821    -0.509625         -0.889329    0.114443
# 10               -0.592355    -0.509625          0.134280    2.866988
# 12               -0.034492     1.747285          1.976775    1.949473
# 13                1.360167    -0.509625          0.134280   -0.619569
# 14               -0.731821    -0.509625         -0.889329   -0.986575
# ...

# %% [markdown]
# # Pearson correlation

# %%
df_grouped_by_student.corr()
# Out:
#                      AttributeError  ImportError  IndentationError  \
# AttributeError             1.000000     0.344568          0.290455
# ImportError                0.344568     1.000000          0.182700
# IndentationError           0.290455     0.182700          1.000000
# IndexError                 0.320137     0.223092          0.166409
# KeyError                   0.137220    -0.099487         -0.065660
# ModuleNotFoundError        0.172033    -0.121360          0.108979
# NameError                  0.553712     0.323396          0.478251
# RecursionError             0.218307     0.067418          0.281874
# SyntaxError                0.547343     0.288906          0.547581
# TypeError                  0.451705     0.390844          0.502996
# UnboundLocalError          0.345955     0.059773          0.183876
# ValueError                 0.309347     0.075897          0.361879
# ZeroDivisionError          0.169200     0.120714          0.128693
# ...

# %%
df_grouped_by_student['SyntaxError'].corr(df_grouped_by_student['Score_excellent'])
# Out:
# 0.032020341318401174

# %%
df_grouped_by_student['SyntaxError'].corr(df_grouped_by_student['Score_failed'])
# Out:
# -0.06708876415140531

# %%
df_grouped_by_student['SyntaxError'].corr(df_grouped_by_student['Score_passed'])
# Out:
# 0.04813360010154437

# %% [markdown]
# # Spearman correlation

# %%
#spearman correlation
df_grouped_by_student.corr(method='spearman')
# Out:
#                      AttributeError  ImportError  IndentationError  \
# AttributeError             1.000000     0.307830          0.249018
# ImportError                0.307830     1.000000          0.075035
# IndentationError           0.249018     0.075035          1.000000
# IndexError                 0.420673     0.272659          0.281823
# KeyError                   0.289805    -0.013489          0.021089
# ModuleNotFoundError        0.335689    -0.049665          0.089217
# NameError                  0.726602     0.354462          0.336377
# RecursionError             0.339897     0.201208          0.169569
# SyntaxError                0.631548     0.274663          0.521399
# TypeError                  0.653936     0.384693          0.401445
# UnboundLocalError          0.486774     0.061752          0.152977
# ValueError                 0.460506     0.091435          0.231470
# ZeroDivisionError          0.268973     0.156759          0.153939
# ...

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_grouped_by_student.corr(),cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
#df_grouped_by_student.describe()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_grouped_by_student.corr() ,cmap="RdBu_r", annot=True)
# Out:
# <AxesSubplot:>

# %%
numero_errori_totali = new_df_errors.shape[0]

numero_errori_type_totali = new_df_errors.loc[new_df_errors['error_type'] == 'TypeError'].shape[0]

numero_errori_type_failed = new_df_errors.loc[(new_df_errors['error_type'] == 'TypeError') & (new_df_errors['score'] == 'failed')].shape[0]
numero_errori_type_passed = new_df_errors.loc[(new_df_errors['error_type'] == 'TypeError') & (new_df_errors['score'] == 'passed')].shape[0]
numero_errori_type_excellent = new_df_errors.loc[(new_df_errors['error_type'] == 'TypeError') & (new_df_errors['score'] == 'excellent')].shape[0]


numero_errori_type_totali
# Out:
# 1711

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_grouped_by_student.corr(method='spearman') ,cmap="RdBu_r", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # p-value

# %%
from scipy.stats import kendalltau, pearsonr, spearmanr
pd.set_option("display.max_columns", None)
def pearsonr_pval(x,y):
        return pearsonr(x,y)[1]

    
pd.set_option('display.float_format', lambda x: '%.7f' % x)    
df_grouped_by_student.corr(method=pearsonr_pval)
# Out:
#                      AttributeError  ImportError  IndentationError  \
# AttributeError            1.0000000    0.0007192         0.0047380
# ImportError               0.0007192    1.0000000         0.0796278
# IndentationError          0.0047380    0.0796278         1.0000000
# IndexError                0.0017582    0.0315953         0.1108868
# KeyError                  0.1896475    0.3427224         0.5317650
# ModuleNotFoundError       0.0991677    0.2465307         0.2984136
# NameError                 0.0000000    0.0015671         0.0000012
# RecursionError            0.0355328    0.5208110         0.0061952
# SyntaxError               0.0000000    0.0049760         0.0000000
# TypeError                 0.0000055    0.0001073         0.0000003
# UnboundLocalError         0.0006821    0.5692573         0.0776764
# ValueError                0.0025507    0.4696385         0.0003649
# ZeroDivisionError         0.1049423    0.2490736         0.2189200
# ...

# %%
#heatmap solo per vedere in modo semplice il p-value

pd.set_option('display.float_format', lambda x: '%.7f' % x)   

plt.figure(figsize=(20,10))
sns.heatmap(df_grouped_by_student.corr(method=pearsonr_pval) ,cmap="RdBu_r", annot=True)
# Out:
# <AxesSubplot:>
